# %%
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# %%
labels = pd.read_csv("C:/Users/yagoa/Downloads/Y_train_eVW9jym.csv")
print(labels)
# Out:
#       Unnamed: 0                                           filename  window  \
# 0              0  15b3bab7c186fd35b65df777890c427dd243feacbb85dd...    2003
# 1              1  1856617e1ac2d821a46a41b938818f0169342226a78f93...    2003
# 2              2  19066cce773b3a092ebf4311b11858aa653da6f8274957...    2003
# 3              3  19c10caf4b24284e1748caed62d94cbb689d6b379b1cf5...    2003
# 4              4  1a627426d55a668df8bcd381a7fa87b620481995b6755f...    2003
# ...          ...                                                ...     ...
# 8273        8273  8c2897ec93e00bd24f68ac7f80152c514f623ef34b7cc4...    2005
# 8274        8274  8d428498436a83b76aa7e982432fb61e427ee8fb7b30b7...    2005
# 8275        8275  9cd1a03a4a6c5decbf700e64f78e02daa86891ec1577d0...    2005
# 8276        8276  e5d19ca1824341c6725858da59f5b856ef3a7a0c3566e2...    2005
# 8277        8277  e66f1f5b57fa9bf046d4f6088027af10bd139121965e86...    2005
#
#         lib           Label
# ...

# %%
miss = labels[labels["Label"] == "Missing"]
good = labels[labels["Label"] == "GOOD"]
lob = labels[labels["Label"] == "Lift-off blanc"]
lon = labels[labels["Label"] == "Lift-off noir"]
bp = labels[labels["Label"] == "Boucle plate"]
mos = labels[labels["Label"] == "Short circuit MOS"]

# %%
os.chdir("C:/Users/yagoa/Downloads/input_train/input_train")
missl = miss["filename"].tolist()
print(missl[0])
img = mpimg.imread(missl[0])
imgplot = plt.imshow(img)
plt.show()
# Out:
# 15b3bab7c186fd35b65df777890c427dd243feacbb85dd5285764c906b59eabd.png

# %%
goodl = good["filename"].tolist()
print(goodl[0])
img = mpimg.imread(goodl[0])
imgplot = plt.imshow(img)
plt.show()
# Out:
# 1856617e1ac2d821a46a41b938818f0169342226a78f9369a4a2ecb769cb2fa2.png

# %%
lobl = lob["filename"].tolist()
print(lobl[0])
img = mpimg.imread(lobl[0])
imgplot = plt.imshow(img)
plt.show()
# Out:
# 0c48bbf9122bb88b72949439ddcbd65000746249067b228c4da9fbe7cb288b8b.png

# %%
lonl = lon["filename"].tolist()
img = mpimg.imread(lonl[0])
imgplot = plt.imshow(img)
plt.show()

# %%
bpl = bp["filename"].tolist()
img = mpimg.imread(bpl[0])
imgplot = plt.imshow(img)
plt.show()

# %%
mosl = mos["filename"].tolist()
print(mosl[3])
img = mpimg.imread(mosl[0])
imgplot = plt.imshow(img)
plt.show()
# Out:
# 1333822949b72feaef23ec0352bb26d790467931e51073d75dbb0b6b500067f7.png
